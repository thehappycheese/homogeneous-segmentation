# %%
library("data.table")
library("HS")
# Out:
# Warning message:
# "package 'data.table' was built under R version 4.1.2"
# Warning message:
# "package 'HS' was built under R version 4.1.2"

# %%
# prepare dummy input

var_a <- c(
	1,
	2,
	3,
	4,
	2,
	3,
	1,
	5,
	3,
	4,
	6,
	4,
	3,
	7,
	5,
	6,
	4,
	5
)

var_b <- c(
	3,
	2,
	1,
	3,
	5,
	6,
	5,
	6,
	4,
	7,
	9,
	4,
	3,
	2,
	3,
	1,
	3,
	2
)

slk_from <- c(
	0.000,
	0.010,
	0.020,
	0.030,
	0.040,
	0.050,
	0.060,
	0.070,
	0.080,
	0.090,
	0.100,
	0.110,
	0.120,
	0.130,
	0.140,
	0.150,
	0.160,
	0.170
)

slk_to <- c(
	0.010,
	0.020,
	0.030,
	0.040,
	0.050,
	0.060,
	0.070,
	0.080,
	0.090,
	0.100,
	0.110,
	0.120,
	0.130,
	0.140,
	0.150,
	0.160,
	0.170,
	0.180
)

length <- c(
	0.010,
	0.010,
	0.010,
	0.010,
	0.010,
	0.010,
	0.010,
	0.010,
	0.010,
	0.010,
	0.010,
	0.010,
	0.010,
	0.010,
	0.010,
	0.010,
	0.010,
	0.010
)

data <- as.data.table(data.frame(var_a, var_b, slk_from, slk_to, length))
#data = data.frame(var_a,var_b,slk_from,slk_to,length)
data
# Out:
#    var_a var_b slk_from slk_to length
# 1  1     3     0.00     0.01   0.01
# 2  2     2     0.01     0.02   0.01
# 3  3     1     0.02     0.03   0.01
# 4  4     3     0.03     0.04   0.01
# 5  2     5     0.04     0.05   0.01
# 6  3     6     0.05     0.06   0.01
# 7  1     5     0.06     0.07   0.01
# 8  5     6     0.07     0.08   0.01
# 9  3     4     0.08     0.09   0.01
# 10 4     7     0.09     0.10   0.01
# 11 6     9     0.10     0.11   0.01
# 12 4     4     0.11     0.12   0.01
# 13 3     3     0.12     0.13   0.01
# 14 7     2     0.13     0.14   0.01
# 15 5     3     0.14     0.15   0.01
# 16 6     1     0.15     0.16   0.01
# 17 4     3     0.16     0.17   0.01
# 18 5     2     0.17     0.18   0.01

# %%
seg1 <- hs(start = "slk_from", end = "slk_to", var = c("var_a","var_b"),
             data = data, method = "shs", range = c(0.02, 0.1))
write.csv(seg1,"..\\test\\r_outputs\\df1_seg_test_out.csv", row.names = FALSE)
seg1
# Out:
#    var_a var_b slk_from slk_to length seg.id seg.point
# 1  1     3     0.00     0.01   0.01   1      1
# 2  2     2     0.01     0.02   0.01   1      0
# 3  3     1     0.02     0.03   0.01   1      0
# 4  4     3     0.03     0.04   0.01   1      0
# 5  2     5     0.04     0.05   0.01   1      0
# 6  3     6     0.05     0.06   0.01   1      0
# 7  1     5     0.06     0.07   0.01   1      0
# 8  5     6     0.07     0.08   0.01   2      1
# 9  3     4     0.08     0.09   0.01   2      0
# 10 4     7     0.09     0.10   0.01   2      0
# 11 6     9     0.10     0.11   0.01   2      0
# 12 4     4     0.11     0.12   0.01   2      0
# 13 3     3     0.12     0.13   0.01   2      0
# 14 7     2     0.13     0.14   0.01   3      1
# 15 5     3     0.14     0.15   0.01   3      0
# 16 6     1     0.15     0.16   0.01   3      0
# 17 4     3     0.16     0.17   0.01   3      0
# 18 5     2     0.17     0.18   0.01   3      0

# %%
df2 <- read.csv("../test/test_data/df2.csv")
df2
# Out:
#       road slk_from slk_to cwy deflection
# 1     H001 0.00     0.01   L   179.37
# 2     H001 0.01     0.02   L   177.12
# 3     H001 0.02     0.03   L   179.06
# 4     H001 0.03     0.04   L   212.65
# 5     H001 0.04     0.05   L   175.35
# 6     H001 0.05     0.06   L   188.66
# 7     H001 0.06     0.07   L   188.31
# 8     H001 0.07     0.08   L   174.48
# 9     H001 0.08     0.09   L   210.28
# 10    H001 0.09     0.10   L   260.05
# 11    H001 0.10     0.11   L   228.83
# 12    H001 0.11     0.12   L   226.33
# 13    H001 0.12     0.13   L   245.53
# 14    H001 0.13     0.14   L   315.77
# 15    H001 0.14     0.15   L   373.86
# 16    H001 0.15     0.16   L   333.56
# 17    H001 0.16     0.17   L   266.55
# 18    H001 0.17     0.18   L   238.89
# 19    H001 0.18     0.19   L   265.29
# 20    H001 0.19     0.20   L   237.29
# 21    H001 0.20     0.21   L   282.93
# 22    H001 0.21     0.22   L   319.23
# 23    H001 0.22     0.23   L   332.83
# 24    H001 0.23     0.24   L   350.71
# 25    H001 0.24     0.25   S   330.31
# 26    H001 0.25     0.26   S   327.75
# 27    H001 0.26     0.27   S   381.52
# 28    H001 0.27     0.28   S   501.02
# 29    H001 0.28     0.29   S   531.58
# 30    H001 0.29     0.30   S   556.21
# ...   ...  ...      ...    ... ...
# 17040 H001 35.79    35.80  S   237.62
# 17041 H001 35.80    35.81  S   193.75
# 17042 H001 35.81    35.82  S   188.34
# 17043 H001 35.82    35.83  S   140.17
# 17044 H001 35.83    35.84  S   196.92
# 17045 H001 35.84    35.85  S   302.80
# 17046 H001 35.85    35.86  S   310.87
# 17047 H001 35.86    35.87  S   294.21
# 17048 H001 35.87    35.88  S   310.03
# 17049 H001 35.88    35.89  S   282.11
# 17050 H001 35.89    35.90  S   248.11
# 17051 H001 35.90    35.91  S   254.67
# 17052 H001 35.91    35.92  S   252.37
# 17053 H001 35.92    35.93  S   279.18
# 17054 H001 35.93    35.94  S   301.42
# 17055 H001 35.94    35.95  S   228.15
# 17056 H001 35.95    35.96  S   198.16
# 17057 H001 35.96    35.97  S   217.28
# 17058 H001 35.97    35.98  S   219.35
# 17059 H001 35.98    35.99  S   236.64
# 17060 H001 35.99    36.00  S   230.58
# 17061 H001 36.00    36.01  S   201.33
# 17062 H001 36.01    36.02  S   241.61
# 17063 H001 36.02    36.03  S   249.55
# 17064 H001 36.03    36.04  S   224.32
# 17065 H001 36.04    36.05  S   217.21
# 17066 H001 36.05    36.06  S   255.90
# 17067 H001 36.06    36.07  S   311.99
# 17068 H001 36.07    36.08  S   299.76
# 17069 H001 36.08    36.09  S   252.60

# %%
df2 <- df2[
      (df2["road"]=="H001")
    & (df2["cwy"]=="S")
    & (df2["dirn"]=="L")
    & (df2["slk_from"]>50)
    & (df2["slk_from"]<60)
    ,
]
df2
# Out:
#       road slk_from slk_to cwy deflection
# 4944  H001 50.01    50.02  S   146.27
# 4945  H001 50.02    50.03  S   144.29
# 4946  H001 50.03    50.04  S   167.12
# 4947  H001 50.04    50.05  S   229.80
# 4948  H001 50.05    50.06  S   163.26
# 4949  H001 50.06    50.07  S   141.11
# 4950  H001 50.07    50.08  S   224.18
# 4951  H001 50.08    50.09  S   192.37
# 4952  H001 50.09    50.10  S   229.69
# 4953  H001 50.10    50.11  S   204.52
# 4954  H001 50.11    50.12  S   173.55
# 4955  H001 50.12    50.13  S   201.83
# 4956  H001 50.13    50.14  S   185.63
# 4957  H001 50.14    50.15  S   151.16
# 4958  H001 50.15    50.16  S   191.56
# 4959  H001 50.16    50.17  S   184.69
# 4960  H001 50.17    50.18  S   160.80
# 4961  H001 50.18    50.19  S   238.29
# 4962  H001 50.19    50.20  S   240.41
# 4963  H001 50.20    50.21  S   203.82
# 4964  H001 50.21    50.22  S   187.05
# 4965  H001 50.22    50.23  S   170.83
# 4966  H001 50.23    50.24  S   203.68
# 4967  H001 50.24    50.25  S   244.58
# 4968  H001 50.25    50.26  S   237.08
# 4969  H001 50.26    50.27  S   214.29
# 4970  H001 50.27    50.28  S   199.49
# 4971  H001 50.28    50.29  S   211.48
# 4972  H001 50.29    50.30  S   285.63
# 4973  H001 50.30    50.31  S   208.76
# ...   ...  ...      ...    ... ...
# 13531 H001 50.80    50.81  S   614.08
# 13532 H001 50.81    50.82  S   646.75
# 13533 H001 50.82    50.83  S   615.74
# 13534 H001 50.83    50.84  S   543.92
# 13535 H001 50.84    50.85  S   517.08
# 13536 H001 50.85    50.86  S   559.14
# 13537 H001 50.86    50.87  S   460.20
# 13538 H001 50.87    50.88  S   679.64
# 13539 H001 50.88    50.89  S   561.40
# 13540 H001 50.89    50.90  S   473.90
# 13541 H001 50.90    50.91  S   370.35
# 13542 H001 50.91    50.92  S   457.40
# 13543 H001 50.92    50.93  S   606.85
# 13544 H001 50.93    50.94  S   611.00
# 13545 H001 50.94    50.95  S   492.83
# 13546 H001 50.95    50.96  S   490.52
# 13547 H001 50.96    50.97  S   491.08
# 13548 H001 50.97    50.98  S   524.65
# 13549 H001 50.98    50.99  S   419.42
# 13550 H001 50.99    51.00  S   471.77
# 13551 H001 51.00    51.01  S   518.20
# 13552 H001 51.01    51.02  S   551.61
# 13553 H001 51.02    51.03  S   440.82
# 13554 H001 51.03    51.04  S   417.17
# 13555 H001 51.04    51.05  S   400.49
# 13556 H001 51.05    51.06  S   417.98
# 13557 H001 51.06    51.07  S   431.98
# 13558 H001 51.07    51.08  S   527.30
# 13559 H001 51.08    51.09  S   472.74
# 13560 H001 51.09    51.10  S   352.87

# %%
seg2 <- hs(
    start = "slk_from",
    end = "slk_to",
    var = c("deflection"),
    data = df2,
    method = "shs",
    range = c(0.050, 0.200)
)
write.csv(seg2,"..\\test\\r_outputs\\df2_seg_test_out.csv", row.names = FALSE)
seg2
